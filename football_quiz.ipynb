# %%
print("Welcome to football quiz!")

playing = input("Do you want to start the quiz? Y/N    ")
answer = ""
score = 0
if playing.lower() != "y":
    exit()
else:
    print("Let's start with the first question!")
    
print()
    
#soru1
answer = input("The Brazil-Germany final played in the 2014 World Cup ended 7-0. [T/F]    ")
if answer.upper() == "T":
    print("You answered correctly!")
    score += 1
else:
    print("You gave the wrong answer.")
    score -= 1
    
print()
    
#soru2
answer = input("BEKO hasn't sponsored Barcelona. [T/F]    ")
if answer.upper() == "F":
    print("You answered correctly!")
    score += 1
else:
    print("You gave the wrong answer.")
    score -= 1 

print()    

#soru3    
answer = input("Fernando Torres is the top goal scorer in Atletico Madrid history. [T/F]    ")
if answer.upper() == "F":
    print("You answered correctly!")
    score += 1
else:
    print("You gave the wrong answer.")
    score -= 1
    
print()
    
#soru4
answer = input("Cristiano Ronaldo is the player with the most penalty goals in the 21st century. [T/F]    ")
if answer.upper() == "T":
    print("You answered correctly!")
    score += 1
else:
    print("You gave the wrong answer.")
    score -= 1 
    
print()

#soru5
answer = input("Manchester City won the 2011/2012 season with Sergio Aguero's last-minute goal. [T/F]    ")
if answer.upper() == "T":
    print("You answered correctly!")
    score += 1
else:
    print("You gave the wrong answer.")
    score -= 1
    
print()
    
#soru6
answer = input("Spain won the 2010 World Cup with Xavi's goal in the 116th minute. [T/F]    ")
if answer.upper() == "F":
    print("You answered correctly!")
    score += 1
else:
    print("You gave the wrong answer.")
    score -= 1 
    
print()
    
#soru7
answer = input("Zlatan Ibrahimovic played football for 9 different teams in his professional career. [T/F]    ")
if answer.upper() == "T":
    print("You answered correctly!")
    score += 1
else:
    print("You gave the wrong answer.")
    score -= 1  
    

print()
if score < 0:
    print("Game is over!")
    print("Your total score: " + str(score))
elif score < 3: 
    print("Average, you passed the quiz!")
else:
    print("Congratulations, you are a football master!")
# Out:
# Welcome to football quiz!
# Do you want to start the quiz? Y/N    n
#   Input In [5]
#     break
#     ^
# SyntaxError: 'break' outside loop
